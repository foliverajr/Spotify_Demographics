# %%
from fycharts.SpotifyCharts import SpotifyCharts

api = SpotifyCharts()
api.top200Daily(output_file = "top_200_annual.csv", start = "2020-02-12", end = "2020-03-12", region=['global'])
# Out:
# INFO : 14/03/2020 12:17:42 AM : Extracting top 200 daily for 2020-02-12 - global
# INFO : 14/03/2020 12:17:43 AM : Extracting top 200 daily for 2020-02-13 - global
# INFO : 14/03/2020 12:17:43 AM : Appending data to the file top_200_annual.csv...
# INFO : 14/03/2020 12:17:43 AM : Done appending to the file top_200_annual.csv!!!
# INFO : 14/03/2020 12:17:44 AM : Extracting top 200 daily for 2020-02-14 - global
# INFO : 14/03/2020 12:17:44 AM : Appending data to the file top_200_annual.csv...
# INFO : 14/03/2020 12:17:44 AM : Done appending to the file top_200_annual.csv!!!
# INFO : 14/03/2020 12:17:45 AM : Extracting top 200 daily for 2020-02-15 - global
# INFO : 14/03/2020 12:17:45 AM : Appending data to the file top_200_annual.csv...
# INFO : 14/03/2020 12:17:45 AM : Done appending to the file top_200_annual.csv!!!
# INFO : 14/03/2020 12:17:46 AM : Extracting top 200 daily for 2020-02-16 - global
# INFO : 14/03/2020 12:17:46 AM : Appending data to the file top_200_annual.csv...
# ...
