# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\aweso\\OneDrive\\Documents\\College\\NJIT\\Spring_2020\\CS_301\\Group Project\\t200_unique_streams.csv")

dict = {}
features = df['featured-artist']
index = 0
for feature in features:    
    if pd.isnull(feature) == True:
        index +=1
        continue
    #print(df.loc[index]['Track Name'])
    song = df['Track Name'][index]
    feature_list = feature.split(', ')
    
    for fe in feature_list:
        if fe not in dict:
            dict[fe]=[song]
        else:
            dict[fe].append(song)
    index +=1
dict
# Out:
# {'Camila Cabello': ['Señorita',
#   'South of the Border (feat. Camila Cabello & Cardi B)',
#   'Find U Again (feat. Camila Cabello)',
#   'Beautiful (feat. Camila Cabello)'],
#  'Justin Bieber': ["I Don't Care (with Justin Bieber)",
#   '10,000 Hours (with Justin Bieber)',
#   'bad guy (with Justin Bieber)',
#   "Don't Check On Me (feat. Justin Bieber & Ink)",
#   'Love Thru The Computer (feat. Justin Bieber)'],
#  'Brendon Urie': ['ME! (feat. Brendon Urie of Panic! At The Disco)',
#   'Roses (with Juice WRLD feat. Brendon Urie)'],
#  'Young Thug': ['Goodbyes (Feat. Young Thug)',
#   'Feels (feat. Young Thug & J Hus)',
#   'Havana (feat. Young Thug)'],
#  'Khalid': ['Beautiful People (feat. Khalid)',
#   'Eastside (with Halsey & Khalid)',
#   'lovely',
#   'lovely (with Khalid)',
#   'Trigger',
#   'Silence',
#   'Hurts 2B Human (feat. Khalid)',
#   'Ocean (feat. Khalid)'],
#  'Billy Ray Cyrus': ['Old Town Road (feat. Billy Ray Cyrus) - Remix',
#   'Old Town Road - Remix'],
#  'Swae Lee': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Close To Me (with Diplo) (feat. Swae Lee)',
#   'Arms Around You (feat. Maluma & Swae Lee)'],
#  'Daddy Yankee': ['China',
#   'Soltera - Remix',
#   'Soltera (Remix)',
#   'Runaway',
#   'Baila Baila Baila - Remix',
#   'Instagram',
#   'Asesina - Remix'],
#  'KAROL G': ['China', 'Secreto', 'Tú No Amas'],
#  'J Balvin': ['China',
#   'RITMO (Bad Boys For Life)',
#   'Loco Contigo (feat. J. Balvin & Tyga)',
#   'Loco Contigo',
#   'Loco Contigo (with J. Balvin & Tyga)',
#   'I Can’t Get Enough (benny blanco, Selena Gomez, J Balvin, Tainy)',
#   'No Me Conoce - Remix',
#   'Con Altura',
#   'I Like It',
#   'Contra La Pared',
#   'Bola Rebola',
#   'Indeciso',
#   'Baila Baila Baila - Remix',
#   'Say My Name',
#   'Qué Pena',
#   'Haute (feat. J Balvin & Chris Brown)',
#   'Que Calor (with J Balvin & El Alfa)'],
#  'Ozuna': ['China',
#   'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#   'Otro Trago - Remix',
#   'Yo x Ti, Tu x Mi',
#   'Adicto (with Anuel AA & Ozuna)',
#   'Te Robaré',
#   'Si Te Vas',
#   'Aventura',
#   'Imposible',
#   'Esclavo de Tus Besos',
#   'Te Boté - Remix',
#   'Taki Taki (feat. Selena Gomez, Ozuna & Cardi B)',
#   'Asesina - Remix'],
#  'Miley Cyrus': ['Don’t Call Me Angel (Charlie’s Angels) (with Miley Cyrus & Lana Del Rey)',
#   'Nothing Breaks Like a Heart (feat. Miley Cyrus)'],
#  'Lana Del Rey': ['Don’t Call Me Angel (Charlie’s Angels) (with Miley Cyrus & Lana Del Rey)'],
#  'Bradley Cooper': ['Shallow'],
#  'Halsey': ['Boy With Luv (feat. Halsey)',
#   'Die For Me (feat. Future & Halsey)',
#   'Eastside (with Halsey & Khalid)',
#   '11 Minutes (with Halsey feat. Travis Barker)',
#   'Closer'],
#  'Social House': ['boyfriend (with Social House)'],
#  'Snow': ['Con Calma', 'Con Calma - Remix'],
#  'Aloe Blacc': ['SOS', 'SOS (feat. Aloe Blacc)'],
#  'Eminem': ['Homicide',
#   'Homicide (feat. Eminem)',
#   'Remember The Name (feat. Eminem & 50 Cent)'],
#  'Ozzy Osbourne': ['Take What You Want (feat. Ozzy Osbourne & Travis Scott)'],
#  'Travis Scott': ['Take What You Want (feat. Ozzy Osbourne & Travis Scott)',
#   'Antisocial (with Travis Scott)',
#   'The London (feat. J. Cole & Travis Scott)',
#   'ZEZE (feat. Travis Scott & Offset)',
#   'Power is Power',
#   'Hot (Remix) [feat. Gunna and Travis Scott]',
#   'Power is Power (feat. The Weeknd & Travis Scott)',
#   'Legacy (feat. Travis Scott & 21 Savage)',
#   'First Off (feat. Travis Scott)',
#   'Celebrate (feat. Travis Scott & Post Malone)',
#   'CHopstix (with Travis Scott)',
#   'CHopstix (feat. Travis Scott)',
#   'Hop Off A Jet (feat. Travis Scott)',
#   'Mile High',
#   'Whip (feat. Travis Scott)'],
#  'Nicki Minaj': ['Tusa',
#   'Hot Girl Summer (feat. Nicki Minaj & Ty Dolla $ign)',
#   'Bad To You (with Normani & Nicki Minaj)',
#   'FEFE',
#   'Woman Like Me (feat. Nicki Minaj)',
#   'Dumb Blonde (feat. Nicki Minaj)',
#   'MAMA'],
#  'DaBaby': ['Enemies (feat. DaBaby)',
#   'My Oh My (feat. DaBaby)',
#   'Hot Shower',
#   'Under The Sun (with J. Cole & Lute feat. DaBaby)',
#   'Baby (Lil Baby feat. DaBaby)',
#   'Panini - DaBaby Remix',
#   'Baby',
#   'Death'],
#  'Darell': ['Otro Trago',
#   'Otro Trago - Remix',
#   'Verte Ir',
#   'Te Boté - Remix',
#   'Asesina - Remix',
#   'Ta To Gucci (Remix)'],
#  'Rick Ross': ['Money In The Grave (Drake ft. Rick Ross)',
#   'Down Like That (feat. Rick Ross, Lil Baby & S-X)'],
#  'Bastille': ['Happier'],
#  'bbno$': ['Lalala'],
#  'Farruko': ['Calma - Remix',
#   'Fantasias',
#   'On My Way',
#   'Que Mas Pues - Remix',
#   'Baila Baila Baila - Remix',
#   'Si Se Da - Remix',
#   'Si Se Da',
#   'DJ No Pare (feat. Zion, Dalex, Lenny Tavárez) - Remix',
#   'Bellaquita - Remix',
#   'El Favor (with Nicky Jam & Sech, feat. Farruko, Zion & Lunay)',
#   'Rebota - Remix',
#   'Pa Olvidarte (feat. Manuel Turizo) - Remix',
#   'Baby',
#   'Que Mas Pues - Remix'],
#  'Normani': ['Dancing With A Stranger (with Normani)',
#   'Bad To You (with Normani & Nicki Minaj)',
#   'Love Lies (with Normani)'],
#  'Selena Gomez': ['Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#   'I Can’t Get Enough (benny blanco, Selena Gomez, J Balvin, Tainy)',
#   'Taki Taki (feat. Selena Gomez, Ozuna & Cardi B)',
#   'Anxiety (with Selena Gomez)'],
#  'Cardi B': ['Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#   'South of the Border (feat. Camila Cabello & Cardi B)',
#   'Rodeo',
#   'Girls Like You (feat. Cardi B)',
#   'Writing on the Wall (feat. Post Malone & Cardi B)',
#   'Wish Wish (feat. Cardi B & 21 Savage)',
#   'Taki Taki (feat. Selena Gomez, Ozuna & Cardi B)',
#   'Clout (feat. Cardi B)',
#   'Thotiana (feat. Cardi B, YG) [Remix]'],
#  'Tainy': ['Callaita',
#   'I Can’t Get Enough (benny blanco, Selena Gomez, J Balvin, Tainy)',
#   'Fuego (with Sean Paul & Anitta, feat. Tainy)'],
#  'Future': ['Die For Me (feat. Future & Halsey)', 'Out The Mud'],
#  'J. Cole': ['The London (feat. J. Cole & Travis Scott)',
#   'Under The Sun (with J. Cole & Lute feat. DaBaby)',
#   'Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)',
#   'How Did I Get Here (feat. J. Cole)',
#   'Sunset (with J. Cole feat. Young Nudy)'],
#  'The Harlem Community Choir': ['Happy Xmas (War Is Over) - Remastered'],
#  'The Plastic Ono Band': ['Happy Xmas (War Is Over) - Remastered'],
#  'Yoko Ono': ['Happy Xmas (War Is Over) - Remastered'],
#  'Meek Mill': ['On The Road (feat. Meek Mill & Lil Baby)',
#   '1000 Nights (feat. Meek Mill & A Boogie Wit da Hoodie)',
#   'Peta (feat. Meek Mill)',
#   'Tap (feat. Meek Mill)'],
#  'Lil Baby': ['On The Road (feat. Meek Mill & Lil Baby)',
#   'Bad Bad Bad (feat. Lil Baby)',
#   'Baby (Lil Baby feat. DaBaby)',
#   'Baby',
#   'TOES (feat. Lil Baby & Moneybagg Yo)',
#   'Down Like That (feat. Rick Ross, Lil Baby & S-X)',
#   'Mac 10'],
#  'Anuel AA': ['Otro Trago - Remix',
#   'Adicto (with Anuel AA & Ozuna)',
#   'Verte Ir',
#   'Adictiva',
#   'Whine Up',
#   'Aventura',
#   'Baila Baila Baila - Remix',
#   'Bubalu',
#   'BEBE',
#   'MALA',
#   'Culpables',
#   'Familia (with Anuel Aa, feat. Bantu) - Spider-Man: Into the Spider-Verse',
#   'Te Quemaste',
#   'Asesina - Remix',
#   'Cambio',
#   'Tú No Amas',
#   'Gan-Ga - Remix'],
#  'Nicky Jam': ['Otro Trago - Remix',
#   'Verte Ir',
#   'Cuaderno',
#   'Que Mas Pues - Remix',
#   'Te Boté - Remix',
#   'El Favor (with Nicky Jam & Sech, feat. Farruko, Zion & Lunay)',
#   'Rebota - Remix',
#   'Baby',
#   'Que Mas Pues - Remix',
#   'Date La Vuelta',
#   'Que Le De'],
#  'Tyga': ['Loco Contigo (feat. J. Balvin & Tyga)',
#   'Loco Contigo',
#   'Loco Contigo (with J. Balvin & Tyga)',
#   'Go Loko (feat. Tyga, Jon Z)',
#   'Startender (feat. Offset and Tyga)',
#   'Light It Up (with Tyga & Chris Brown)',
#   'Wow. - Remix',
#   'Go Loko',
#   'Broke Leg (with Quavo & Tyga)',
#   'Juicy'],
#  'B. Swanson Quartet': ['Let It Snow! Let It Snow! Let It Snow! (with The B. Swanson Quartet)'],
#  'Chance the Rapper': ['Cross Me (feat. Chance the Rapper & PnB Rock)'],
#  'PnB Rock': ['Cross Me (feat. Chance the Rapper & PnB Rock)',
#   'bad vibes forever'],
#  'Drake': ['MIA (feat. Drake)',
#   'No Guidance (feat. Drake)',
#   'Going Bad (feat. Drake)',
#   'LOYAL (feat. Drake)',
#   'Gold Roses (feat. Drake)',
#   "Won't Be Late (feat. Drake)",
#   'No Stylist',
#   'Girls Need Love (with Drake) - Remix',
#   'Look Alive (feat. Drake)',
#   'Yes Indeed',
#   'Never Recover (Lil Baby & Gunna, Drake)'],
#  'Bad Bunny': ['Soltera - Remix',
#   'QUE PRETENDES',
#   'LA CANCIÓN',
#   'No Me Conoce - Remix',
#   'Soltera (Remix)',
#   'I Like It',
#   'MOJAITA',
#   'UN PESO',
#   'Bellacoso',
#   'Te Boté - Remix',
#   'YO LE LLEGO',
#   'COMO UN BEBÉ',
#   'ODIO',
#   'CUIDAO POR AHÍ'],
#  'The Weeknd': ['Lost in the Fire',
#   'Power is Power',
#   'Power is Power (feat. The Weeknd & Travis Scott)',
#   'Price On My Head (feat. The Weeknd)'],
#  '50 Cent': ['Remember The Name (feat. Eminem & 50 Cent)'],
#  'Disclosure': ['Talk (feat. Disclosure)', 'Talk'],
#  'YoungBoy Never Broke Again': ['Bandit (with YoungBoy Never Broke Again)'],
#  'Goodboys': ['Piece Of Your Heart', 'Lose Control'],
#  'Offset': ['ZEZE (feat. Travis Scott & Offset)',
#   'Taste (feat. Offset)',
#   'Startender (feat. Offset and Tyga)',
#   'Enzo (with Sheck Wes, feat. Offset, 21 Savage & Gucci Mane)',
#   'Ric Flair Drip (& Metro Boomin)'],
#  'Ty Dolla $ign': ['Everything We Need',
#   'Nights Like This (feat. Ty Dolla $ign)',
#   'Hot Girl Summer (feat. Nicki Minaj & Ty Dolla $ign)',
#   'Psycho (feat. Ty Dolla $ign)',
#   'Do You Mean (feat. Ty Dolla $ign & bülow)'],
#  'Ant Clemons': ['Everything We Need', 'Water'],
#  'Bruno Mars': ['Please Me',
#   'Wake Up in the Sky',
#   'BLOW (with Chris Stapleton & Bruno Mars)'],
#  'SZA': ['Staring At The Sun (feat. SZA)',
#   'Power is Power (feat. The Weeknd & Travis Scott)',
#   'Just Us (feat. SZA)',
#   'All The Stars (with SZA)',
#   'What Lovers Do'],
#  'CHVRCHES': ['Here With Me'],
#  'John Mayer': ['Outta My Head (with John Mayer)'],
#  'Troye Sivan': ["i'm so tired..."],
#  'Rafa Pabön': ['Pa Mí - Remix', 'Cuaderno', 'Ta To Gucci (Remix)'],
#  'KHEA': ['Pa Mí - Remix'],
#  'Sech': ['Pa Mí - Remix',
#   'Quizas',
#   'Sigues Con El',
#   'Cuaderno',
#   'Si Se Da - Remix',
#   'Quizás',
#   'El Favor (with Nicky Jam & Sech, feat. Farruko, Zion & Lunay)',
#   'Rebota - Remix',
#   'Atrévete'],
#  'Cazzu': ['Pa Mí - Remix'],
#  'Feid': ['Pa Mí - Remix', 'Quizas', 'Cuaderno', 'Quizás'],
#  'Lenny Tavárez': ['Pa Mí - Remix',
#   'Hola - Remix',
#   'Quizas',
#   'Cuaderno',
#   'Que Mas Pues - Remix',
#   'Quizás',
#   'DJ No Pare (feat. Zion, Dalex, Lenny Tavárez) - Remix',
#   'Bellaquita - Remix',
#   'Bellaquita',
#   'Que Mas Pues - Remix'],
#  'Ken Darby Singers': ['White Christmas'],
#  'John Scott Trotter & His Orchestra': ['White Christmas'],
#  'Macklemore': ['Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)',
#   "I Don't Belong In This Club",
#   'These Days (feat. Jess Glynne, Macklemore & Dan Caplen)'],
#  'Fall Out Boy': ['Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)',
#   "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)"],
#  'Bebe Rexha': ['Call You Mine',
#   'Say My Name',
#   'Call You Mine (feat. Bebe Rexha)',
#   'Harder (with Bebe Rexha)'],
#  'Clipse': ['Use This Gospel'],
#  'Kenny G': ['Use This Gospel'],
#  "Rag'n'Bone Man": ["Giant (with Rag'n'Bone Man)"],
#  'Victoria Monét': ['MONOPOLY (with Victoria Monét)'],
#  'Gunna': ['Drip Too Hard (Lil Baby & Gunna)',
#   'Hot (Remix) [feat. Gunna and Travis Scott]',
#   'Stuck In A Dream (feat. Gunna)',
#   'Hot (feat. Gunna)',
#   'Space Cadet (feat. Gunna)',
#   'I Wanna Rock (feat. Gunna)',
#   'Start Wit Me (feat. Gunna)',
#   'Never Recover (Lil Baby & Gunna, Drake)',
#   'Surf (feat. Gunna)'],
#  'Pedro Capó': ['Tutu'],
#  '5 Seconds of Summer': ['Who Do You Love'],
#  'ZAYN': ['Trampoline (with ZAYN)'],
#  '6ix9ine': ['Swervin (feat. 6ix9ine)'],
#  'Yebba': ['Best Part of Me (feat. YEBBA)'],
#  'Diplo': ['Close To Me (with Diplo) (feat. Swae Lee)',
#   'Trigger',
#   'Que Calor (with J Balvin & El Alfa)',
#   'Electricity (with Dua Lipa)',
#   'No New Friends',
#   'No New Friends (feat. Sia, Diplo, and Labrinth)',
#   'Thunderclouds'],
#  'Whitney Houston': ['Higher Love'],
#  'Lil Pump': ['Arms Around You (feat. Maluma & Swae Lee)',
#   'I Love It (& Lil Pump)'],
#  'Maluma': ['Arms Around You (feat. Maluma & Swae Lee)',
#   'Que Mas Pues - Remix',
#   'Créeme',
#   'Amigos Con Derechos',
#   'Que Mas Pues - Remix'],
#  'Stormzy': ['Take Me Back to London (feat. Stormzy)'],
#  'Samra': ['Tilidin',
#   '110',
#   'Wir ticken',
#   'Royal Rumble',
#   'Nummer 1',
#   'Berlin lebt wie nie zuvor',
#   'Ya Salame'],
#  'Sunday Service Choir': ['Every Hour'],
#  'ILLENIUM': ['Takeaway (feat. Lennon Stella)', 'Takeaway'],
#  'Lennon Stella': ['Takeaway (feat. Lennon Stella)', 'Takeaway'],
#  'Mambo Kingz': ['Verte Ir', 'Bubalu'],
#  'Brytiago': ['Verte Ir', 'Ta To Gucci (Remix)'],
#  'Anne-Marie': ["fuck, i'm lonely",
#   'Rewrite The Stars (with James Arthur & Anne-Marie)',
#   'FRIENDS',
#   "fuck, i'm lonely (with Anne-Marie) - from “13 Reasons Why: Season 3”"],
#  'Kane Brown': ['One Thing Right'],
#  'Ariana Grande': ['Good as Hell (feat. Ariana Grande) - Remix',
#   'Rule The World (feat. Ariana Grande)'],
#  'El Guincho': ['Con Altura'],
#  'Kirsty MacColl': ['Fairytale of New York (feat. Kirsty MacColl)'],
#  'Game of Thrones': ['Power is Power'],
#  '9lokknine': ["223's (feat. 9lokknine)"],
#  'The Fontane Sisters': ["It's Beginning to Look a Lot Like Christmas (with Mitchell Ayres & His Orchestra)"],
#  'Mitchell Ayres & His Orchestra': ["It's Beginning to Look a Lot Like Christmas (with Mitchell Ayres & His Orchestra)"],
#  'LANY': ['Mean It'],
#  'Rita Ora': ['Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu")',
#   'R.I.P. (feat. Rita Ora & Anitta)',
#   'Ritual'],
#  'Winona Oak': ['Hope'],
#  'Anitta': ['R.I.P. (feat. Rita Ora & Anitta)',
#   'Bola Rebola',
#   'Bellaquita - Remix',
#   'Fuego (with Sean Paul & Anitta, feat. Tainy)'],
#  'Ink': ["Don't Check On Me (feat. Justin Bieber & Ink)"],
#  'Manuel Turizo': ['Desconocidos',
#   'Vaina Loca',
#   'Pa Olvidarte (feat. Manuel Turizo) - Remix',
#   'Dile la Verdad'],
#  'Camilo': ['Desconocidos', 'La Boca', 'La Boca - Remix'],
#  'LEA': ['110'],
#  'Paulo Londra': ['Nothing On You (feat. Paulo Londra & Dave)',
#   'Cuando Te Besé'],
#  'Dave': ['Nothing On You (feat. Paulo Londra & Dave)'],
#  'Shawn Mendes': ['Lover (Remix) [feat. Shawn Mendes]'],
#  'Lil Tjay': ['Pop Out (feat. Lil Tjay)'],
#  'Burna Boy': ['Own It (feat. Ed Sheeran & Burna Boy)',
#   'Be Honest (feat. Burna Boy)',
#   'Be Honest'],
#  'Ed Sheeran': ['Own It (feat. Ed Sheeran & Burna Boy)'],
#  'Sabrina Carpenter': ['On My Way'],
#  'Becky Hill': ['Lose Control'],
#  'Jon Z': ['Go Loko (feat. Tyga, Jon Z)', 'Go Loko'],
#  'Fred Hammond': ['Hands On'],
#  "Gigi D'Agostino": ['In My Mind'],
#  'Romeo Santos': ['Ella Quiere Beber - Remix', 'Aullando', 'Ibiza'],
#  'Migos': ['Pure Water (with Migos)', 'RAW SHIT (feat. Migos)'],
#  'Juice WRLD': ['Hate Me (with Juice WRLD)',
#   '6 Kiss',
#   'Ransom (with Juice WRLD) - Remix',
#   'Graduation (with Juice WRLD)',
#   'Roses (with Juice WRLD feat. Brendon Urie)',
#   'Fine China',
#   'Nuketown (feat. Juice WRLD)',
#   'All Night (BTS World Original Soundtrack) [Pt. 3]'],
#  'Agnes': ['Tough Love', 'Tough Love (feat. Agnes, Vargas & Lagola)'],
#  'Vargas & Lagola': ['Tough Love',
#   'Tough Love (feat. Agnes, Vargas & Lagola)'],
#  'Logic': ['Isis'],
#  'Britney Spears': ['My Only Wish (This Year)'],
#  'Katy Perry': ['365', 'Con Calma - Remix'],
#  'Haze': ['Amanece'],
#  'Zhavia Ward': ['A Whole New World (End Title) - From "Aladdin"'],
#  'Capital Bra': ['Wieder Lila',
#   'Zombie',
#   'Huracan',
#   'Royal Rumble',
#   'DNA',
#   'Diamonds (feat. Capital Bra)'],
#  '21 Savage': ['rockstar (feat. 21 Savage)',
#   'Legacy (feat. Travis Scott & 21 Savage)',
#   'Floating (feat. 21 Savage)',
#   'Wish Wish (feat. Cardi B & 21 Savage)',
#   'Focus (feat. 21 Savage)',
#   'Enzo (with Sheck Wes, feat. Offset, 21 Savage & Gucci Mane)',
#   '10 Freaky Girls (with 21 Savage)'],
#  'Kodak Black': ['Wake Up in the Sky'],
#  'Sam Smith': ['Promises (with Sam Smith)'],
#  'Jessie Reyez': ['Promises (with Sam Smith)'],
#  'Lauv': ['Make It Right (feat. Lauv)'],
#  'Death Stranding: Timefall': ['Trigger'],
#  'RM': ['Old Town Road (feat. RM of BTS) - Seoul Town Road Remix'],
#  'BTS': ['Old Town Road (feat. RM of BTS) - Seoul Town Road Remix',
#   "SUGA's Interlude"],
#  'Micro TDH': ['Te Vi'],
#  'Rvssian': ['Writing on the Wall (feat. Post Malone & Cardi B)',
#   'Ring Ring (with Rvssian feat. Clever)'],
#  'Post Malone': ['Writing on the Wall (feat. Post Malone & Cardi B)',
#   'Celebrate (feat. Travis Scott & Post Malone)',
#   'Jackie Chan'],
#  'SAFE': ["Don't Pretend (feat. SAFE)"],
#  'Charli XCX': ['Dream Glow (BTS World Original Soundtrack) - Pt. 1'],
#  'Reik': ['Un Año'],
#  'Dixie Chicks': ['Soon You’ll Get Better (feat. Dixie Chicks)'],
#  'Natti Natasha': ['Runaway',
#   'Instagram',
#   'DJ No Pare (feat. Zion, Dalex, Lenny Tavárez) - Remix',
#   'Bellaquita - Remix',
#   'Sin Pijama'],
#  'Jonas Brothers': ['Runaway', 'Lonely (with Jonas Brothers)'],
#  'Valerie Broussard': ['Think About You'],
#  'Liz Gillies': ['Santa Baby'],
#  'Chencho Corleone': ['Hola - Remix', 'Ta To Gucci (Remix)'],
#  'Juhn': ['Hola - Remix'],
#  'Dimelo Flow': ['Hola - Remix', 'Quizás'],
#  'Travis Barker': ['11 Minutes (with Halsey feat. Travis Barker)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'A Touch Of Class': ['All Around The World (La La La)'],
#  'RANI': ['Post Malone (feat. RANI)'],
#  'Kanye West': ['Mixed Personalities (feat. Kanye West)', 'MAMA'],
#  'Ella Mai': ['Put It All on Me (feat. Ella Mai)'],
#  'MERO': ['Ferrari', 'Kein Plan'],
#  'J Hus': ['Feels (feat. Young Thug & J Hus)'],
#  'Dalex': ['Quizas',
#   'Que Mas Pues - Remix',
#   'Quizás',
#   'DJ No Pare (feat. Zion, Dalex, Lenny Tavárez) - Remix',
#   'Que Mas Pues - Remix'],
#  'Justin Quiles': ['Quizas',
#   'Cuaderno',
#   'Que Mas Pues - Remix',
#   'Quizás',
#   'Bellaquita - Remix',
#   'Solo Pienso En Ti (feat. De La Ghetto & Justin Quiles)',
#   'Que Mas Pues - Remix'],
#  'Wisin': ['Quizas', 'Quizás'],
#  'Zion': ['Quizas',
#   'Si Se Da - Remix',
#   'Quizás',
#   'DJ No Pare (feat. Zion, Dalex, Lenny Tavárez) - Remix',
#   'El Favor (with Nicky Jam & Sech, feat. Farruko, Zion & Lunay)'],
#  'BLACKPINK': ['Kiss and Make Up'],
#  'Chris Stapleton': ['BLOW (with Chris Stapleton & Bruno Mars)'],
#  'AURORA': ['Into the Unknown'],
#  'Henning May': ['Vermissen (feat. Henning May)'],
#  'Chelsea Cutler': ['Not Ok'],
#  'Kehlani': ['Good Thing (with Kehlani)'],
#  'A Boogie Wit da Hoodie': ['1000 Nights (feat. Meek Mill & A Boogie Wit da Hoodie)',
#   'Baguettes in the Face (feat. NAV, Playboi Carti & A Boogie Wit da Hoodie)',
#   'Right Back (feat. A Boogie Wit Da Hoodie)',
#   'Tip Toe (feat. A Boogie Wit da Hoodie)',
#   'Somebody'],
#  'YNW Melly': ['6 Kiss'],
#  'Arcangel': ['Sigues Con El', 'Si Se Da - Remix', 'Tú No Amas'],
#  'Blake Shelton': ['You Make It Feel Like Christmas (feat. Blake Shelton)'],
#  'JAY-Z': ['MOOD 4 EVA (feat. Oumou Sangaré)'],
#  'Childish Gambino': ['MOOD 4 EVA (feat. Oumou Sangaré)'],
#  'Oumou Sangaré': ['MOOD 4 EVA (feat. Oumou Sangaré)'],
#  'Chris Brown': ['Light It Up (with Tyga & Chris Brown)',
#   'Haute (feat. J Balvin & Chris Brown)',
#   'Jealous (feat. Chris Brown, Lil Wayne & Big Sean)'],
#  'Mc Zaac': ['Bola Rebola'],
#  'Roddy Ricch': ['Racks in the Middle (feat. Roddy Ricch and Hit-Boy)',
#   "Ballin' (with Roddy Ricch)",
#   'Wow. - Remix',
#   'Project Dreams'],
#  'Hit-Boy': ['Racks in the Middle (feat. Roddy Ricch and Hit-Boy)',
#   'Bezerk (feat. A$AP Ferg)'],
#  'Lalo Ebratt': ['Indeciso'],
#  'Brando': ['Body (feat. brando)'],
#  'YUNGBLUD': ["I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Tongue Tied (with YUNGBLUD & blackbear)'],
#  'Skrillex': ['Way To Break My Heart (feat. Skrillex)'],
#  'MadeinTYO': ['Hot Shower'],
#  'Henri Rene & His Orchestra': ['Santa Baby (with Henri René & His Orchestra)'],
#  'H.E.R.': ["I Don't Want Your Money (feat. H.E.R.)"],
#  'Prince Royce': ['Bubalu'],
#  'DJ Luian': ['Bubalu', 'Tú No Amas'],
#  'Jonas Blue': ['Ritual'],
#  'Lute': ['Under The Sun (with J. Cole & Lute feat. DaBaby)'],
#  'Summer Cem': ['Rolex', 'DNA'],
#  'KC Rebell': ['Rolex'],
#  'Tory Lanez': ['KIKA'],
#  'Shania Twain': ['White Christmas (with Shania Twain)'],
#  'Sandro Cavazza': ['Happy Now'],
#  'Mykola Dmytrovych Leontovych': ['Carol of the Bells'],
#  'Dua Lipa': ['One Kiss (with Dua Lipa)', 'Electricity (with Dua Lipa)'],
#  'Meghan Trainor': ["Baby, It's Cold Outside"],
#  'blackbear': ['Tongue Tied (with YUNGBLUD & blackbear)'],
#  'MadMan': ['Veleno 7'],
#  'Trippie Redd': ['bad vibes forever', 'Fuck Love (feat. Trippie Redd)'],
#  'David Guetta': ['Instagram'],
#  'Afro Bros': ['Instagram'],
#  'Dimitri Vegas': ['Instagram'],
#  'Like Mike': ['Instagram'],
#  'El Alfa': ['Que Calor (with J Balvin & El Alfa)'],
#  'Bonez MC': ['Honda Civic'],
#  'Kygo': ['Family'],
#  'Demi Lovato': ['Solo (feat. Demi Lovato)'],
#  'Imanbek': ['Roses - Imanbek Remix'],
#  'Snøw': ['Get You The Moon (feat. Snøw)'],
#  'Marciano Cantero': ['UN PESO'],
#  'The Puppini Sisters': ['Jingle Bells (feat. The Puppini Sisters)'],
#  'Nipsey Hussle': ['Higher (feat. Nipsey Hussle & John Legend)'],
#  'John Legend': ['Higher (feat. Nipsey Hussle & John Legend)', 'All Day Long'],
#  'Hava': ['KEIN SCHLAF'],
#  'Martin Solveig': ['All Day And Night - Jax Jones & Martin Solveig Present Europa',
#   'Thing For You (With Martin Solveig)',
#   'All Day And Night'],
#  'Madison Beer': ['All Day And Night - Jax Jones & Martin Solveig Present Europa',
#   'All Day And Night'],
#  'Europa': ['All Day And Night - Jax Jones & Martin Solveig Present Europa',
#   'All Day And Night'],
#  'Theresa Rex': ['What I Like About You (feat. Theresa Rex)'],
#  'T-Pain': ['Jerry Sprunger (with T-Pain)'],
#  'Lil Uzi Vert': ['Reply (feat. Lil Uzi Vert)',
#   "What's the Move (feat. Lil Uzi Vert)"],
#  'Julia Michaels': ['Lie To Me (feat. Julia Michaels)',
#   'If the World Was Ending - feat. Julia Michaels'],
#  'JID': ['Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)',
#   'Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Bas': ['Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)',
#   'Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'EARTHGANG': ['Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)'],
#  'Young Nudy': ['Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)',
#   'Sunset (with J. Cole feat. Young Nudy)'],
#  'Casper Magico': ['Te Boté - Remix'],
#  'Krono': ['Dancin (feat. Luvli) - Krono Remix'],
#  'Luvli': ['Dancin (feat. Luvli) - Krono Remix'],
#  'Lunay': ['El Favor (with Nicky Jam & Sech, feat. Farruko, Zion & Lunay)',
#   'La Boca - Remix'],
#  'Daniel Caesar': ['Best Part (feat. Daniel Caesar)'],
#  'Maître Gims': ['ON OFF (feat. Maître Gims)'],
#  'Blue Ivy': ['BROWN SKIN GIRL'],
#  'SAINt JHN': ['BROWN SKIN GIRL'],
#  'WizKid': ['BROWN SKIN GIRL'],
#  'David Bowie': ['Under Pressure - Remastered'],
#  'Chris Jeday': ['Soltera'],
#  'Gaby Music': ['Soltera'],
#  'Wisin & Yandel': ['Si Supieras'],
#  'Nicki Nicole': ['Nicki Nicole: Bzrp Music Sessions, Vol. 13'],
#  'Dean Lewis': ['Used To Love (with Dean Lewis)'],
#  'Bonn': ['No Sleep (feat. Bonn)'],
#  'XXXTENTACION': ['Falling Down - Bonus Track'],
#  'Becky G': ['Rebota - Remix',
#   'Chicken Noodle Soup (feat. Becky G)',
#   'GIANTS'],
#  'Erika Sirola': ['Speechless (feat. Erika Sirola)'],
#  'Blueface': ['Shotta Flow (Feat. Blueface) [Remix]'],
#  'Nimo': ['Royal Rumble'],
#  'Luciano': ['Royal Rumble', 'Summer Cem (feat. Luciano)', 'Gib Gas'],
#  'NAV': ['Baguettes in the Face (feat. NAV, Playboi Carti & A Boogie Wit da Hoodie)'],
#  'Playboi Carti': ['Baguettes in the Face (feat. NAV, Playboi Carti & A Boogie Wit da Hoodie)'],
#  'SUGA': ["SUGA's Interlude"],
#  'Zara Larsson': ['A Brand New Day (BTS World Original Soundtrack) [Pt. 2]'],
#  'Murda Beatz': ['FEFE', 'GRoCERIES'],
#  'Mark Linett': ['Little Saint Nick - 1991 Remix'],
#  'Sweet': ['Little Saint Nick - 1991 Remix'],
#  'Larry Walsh': ['Little Saint Nick - 1991 Remix'],
#  'OneRepublic': ['Bones (feat. OneRepublic)'],
#  "Heuss L'enfoiré": ['Ne reviens pas'],
#  'Kelsea Ballerini': ['This Feeling'],
#  'Maren Morris': ['The Middle'],
#  'Grey': ['The Middle'],
#  'Jack & Jack': ['Rise'],
#  'Mau y Ricky': ['Ya No Tiene Novio'],
#  'Bausa': ['Keine Liebe'],
#  'Victor Cardenas': ['Baila Conmigo (feat. Kelly Ruiz)'],
#  'Kelly Ruíz': ['Baila Conmigo (feat. Kelly Ruiz)'],
#  'Lil Wayne': ['Be Like Me (feat. Lil Wayne)',
#   'Jealous (feat. Chris Brown, Lil Wayne & Big Sean)'],
#  'Animus': ['Ronin'],
#  'Lexa': ['Combatchy (feat. MC Rebecca)'],
#  'Luísa Sonza': ['Combatchy (feat. MC Rebecca)'],
#  'Mc Rebecca': ['Combatchy (feat. MC Rebecca)'],
#  'Niska': ['Maman ne le sait pas (feat. Niska)'],
#  'Dani Faiv': ['YOSHI (feat. Fabri Fibra) - prod. Strage'],
#  'tha Supreme': ['YOSHI (feat. Fabri Fibra) - prod. Strage',
#   "SUPREME - L'ego (feat. tha Supreme & Sfera Ebbasta)"],
#  'Fabri Fibra': ['YOSHI (feat. Fabri Fibra) - prod. Strage'],
#  'Apache 207': ['2002'],
#  'Data Luv': ['Shot'],
#  'MC Kevinho': ['Terremoto', 'Agora é Tudo Meu'],
#  'Bantu': ['Familia (with Anuel Aa, feat. Bantu) - Spider-Man: Into the Spider-Verse'],
#  'Bryson Tiller': ['Playing Games (with Bryson Tiller) - Extended Version'],
#  'Zendaya': ['All For Us - from the HBO Original Series Euphoria',
#   'Rewrite The Stars'],
#  'Mark Ronson': ['Electricity (with Dua Lipa)'],
#  'De La Ghetto': ['Solo Pienso En Ti (feat. De La Ghetto & Justin Quiles)'],
#  'Bad Gyal': ['Alocao (With Bad Gyal)'],
#  'Felix Jaehn': ['So Close'],
#  'Captain Cuts': ['So Close'],
#  'Georgia Ku': ['So Close'],
#  'Damso': ['Tricheur'],
#  'Moneybagg Yo': ['TOES (feat. Lil Baby & Moneybagg Yo)'],
#  'Metro Boomin': ['Mile High', 'Ric Flair Drip (& Metro Boomin)'],
#  'Sfera Ebbasta': ["SUPREME - L'ego (feat. tha Supreme & Sfera Ebbasta)",
#   'Stamm Fort (feat. Sfera Ebbasta)'],
#  'Salmo': ['HO PAURA DI USCIRE 2 - prod. Mace',
#   'MARYLEAN (feat. Marracash) - prod. Low Kidd'],
#  'Lazza': ['HO PAURA DI USCIRE 2 - prod. Mace'],
#  'Zion & Lennox': ['Pa Olvidarte (feat. Manuel Turizo) - Remix',
#   'No Es Justo'],
#  'RAYE': ["Stay (Don't Go Away) [feat. Raye]"],
#  'YG': ['Thotiana (feat. Cardi B, YG) [Remix]', 'MAMACITA'],
#  'Quinn XCII': ['Love Me Less (feat. Quinn XCII)'],
#  'Florida Georgia Line': ['Meant to Be (feat. Florida Georgia Line)',
#   'Let Me Go (with Alesso, Florida Georgia Line & watt)'],
#  'Marshmello': ['Everyday', 'Wolves'],
#  'Guapdad 4000': ['Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Reese LAFLARE': ['Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Jace': ['Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Mez': ['Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Smokepurpp': ['Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Buddy': ['Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Ski Mask The Slump God': ['Costa Rica (with Bas & JID feat. Guapdad 4000, Reese LAFLARE, Jace, Mez, Smokepurpp, Buddy & Ski Mask The Slump God)'],
#  'Labrinth': ['No New Friends',
#   'No New Friends (feat. Sia, Diplo, and Labrinth)',
#   'Thunderclouds'],
#  'LSD': ['No New Friends',
#   'No New Friends (feat. Sia, Diplo, and Labrinth)',
#   'Thunderclouds'],
#  'Gucci Mane': ['Bad Girls (feat. Gucci Mane)',
#   'Icy (feat. Gucci Mane)',
#   'Enzo (with Sheck Wes, feat. Offset, 21 Savage & Gucci Mane)'],
#  'Mr Eazi': ['COMO UN BEBÉ'],
#  'Big Sean': ['Jealous (feat. Chris Brown, Lil Wayne & Big Sean)'],
#  'French Montana': ['Maghreb Gang (feat. French Montana & Khaled)'],
#  'Khaled': ['Maghreb Gang (feat. French Montana & Khaled)'],
#  'Adriana Proenza': ['Can We Kiss Forever?'],
#  'Quavo': ['Congratulations', 'Broke Leg (with Quavo & Tyga)'],
#  'Keke Palmer': ['GIANTS'],
#  'SOYEON of (G)I-DLE': ['GIANTS'],
#  'Duckwrth': ['GIANTS'],
#  'Thutmose': ['GIANTS'],
#  'League of Legends': ['GIANTS'],
#  'Evan Rachel Wood': ['Show Yourself'],
#  'RIN': ['Next'],
#  'Oliver Heldens': ['Turn Me On (feat. Vula)'],
#  'Vula': ['Turn Me On (feat. Vula)'],
#  'bülow': ['Do You Mean (feat. Ty Dolla $ign & bülow)'],
#  'A$AP Ferg': ['Bezerk (feat. A$AP Ferg)'],
#  'Alesso': ['Let Me Go (with Alesso, Florida Georgia Line & watt)'],
#  'watt': ['Let Me Go (with Alesso, Florida Georgia Line & watt)'],
#  'Paloma Mami': ['No Te Debí Besar'],
#  'Alizzz': ['No Te Debí Besar'],
#  'Joyner Lucas': ['Lucky You (feat. Joyner Lucas)'],
#  'Mozzik': ['Eiskalt', 'ROMEO & JULIET'],
#  'Brooks': ["Better When You're Gone"],
#  'Loote': ["Better When You're Gone"],
#  'Christian Nodal': ["Pa' Olvidarme De Ella"],
#  'Imagine Dragons': ['Heart Upon My Sleeve (feat. Imagine Dragons)'],
#  'Santana': ['MAMACITA'],
#  'Usher': ['Come Thru (with Usher)'],
#  'Eno': ['weR mAChT PaRA 2'],
#  'G-Eazy': ['Girls Have Fun (feat. G-Eazy & Rich The Kid)',
#   'COMMANDO (feat. G-Eazy)'],
#  'Rich The Kid': ['Girls Have Fun (feat. G-Eazy & Rich The Kid)'],
#  'Ezhel': ['Wir sind Kral', 'AYA'],
#  'Death Cab for Cutie': ['Do You Remember'],
#  'Dzeko': ['Jackie Chan'],
#  'Preme': ['Jackie Chan'],
#  'TisaKorean': ['GRoCERIES'],
#  'Morgan Wallen': ['Heartless (feat. Morgan Wallen)'],
#  'Tati Zaqui': ['Surtada - Remix Brega Funk'],
#  'OIK': ['Surtada - Remix Brega Funk'],
#  'Ghostface Killah': ['D.R.E.A.M. (feat. Ghostface Killah)'],
#  'Joe Janiak': ['Bad Reputation (feat. Joe Janiak)'],
#  'Sebastian Yatra': ['Oye', 'Date La Vuelta'],
#  'A R I Z O N A': ['Hold The Line (feat. A R I Z O N A)'],
#  'The Rudeboyz': ['Dile la Verdad'],
#  'RAF Camora': ['Neptun', 'Nummer'],
#  'Skepta': ['Praise The Lord (Da Shine) (feat. Skepta)'],
#  'Nitro': ['MARYLEAN (feat. Marracash) - prod. Low Kidd'],
#  'Marracash': ['MARYLEAN (feat. Marracash) - prod. Low Kidd'],
#  'Sheck Wes': ['Enzo (with Sheck Wes, feat. Offset, 21 Savage & Gucci Mane)'],
#  'Ferrugem': ['Atrasadinha - Ao Vivo'],
#  'Lil Tecca': ['Somebody'],
#  'Jess Glynne': ['These Days (feat. Jess Glynne, Macklemore & Dan Caplen)'],
#  'Dan Caplen': ['These Days (feat. Jess Glynne, Macklemore & Dan Caplen)'],
#  'Zuna': ['Hallo Hallo'],
#  'ILOVEMAKONNEN': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)"],
#  'Myke Towers': ['Cuerpo en Venta'],
#  'Rauw Alejandro': ['Cuerpo en Venta'],
#  'Almighty': ['Cuerpo en Venta'],
#  'Cruz Cafuné': ['Contando Lunares (feat. Cruz Cafuné)'],
#  'S-X': ['Down Like That (feat. Rick Ross, Lil Baby & S-X)'],
#  'Coldplay': ['Something Just Like This'],
#  'TINI': ['Sad Song (feat. TINI)'],
#  'Ky-Mani Marley': ['Royalty (feat. Ky-Mani Marley, Stefflon Don & Vybz Kartel)'],
#  'Stefflon Don': ['Royalty (feat. Ky-Mani Marley, Stefflon Don & Vybz Kartel)'],
#  'Vybz Kartel': ['Royalty (feat. Ky-Mani Marley, Stefflon Don & Vybz Kartel)'],
#  'Clever': ['Ring Ring (with Rvssian feat. Clever)'],
#  'Anderson .Paak': ['RNP (feat. Anderson .Paak)'],
#  'Niall Horan': ['What A Time (feat. Niall Horan)'],
#  'Cosculluela': ['Ta To Gucci (Remix)'],
#  'Sean Paul': ['Fuego (with Sean Paul & Anitta, feat. Tainy)'],
#  'Lil Duke': ['Mac 10'],
#  'Barloe Team': ['Te Soñé de Nuevo'],
#  'Elley Duhé': ['Happy Now']}

# %%
featured_Drake = df.loc[df['featured-artist']=='Drake']

Bad_Bunny = df.loc[df['Artist']=='Bad Bunny']
Chris_Brown = df.loc[df['Artist']=='Chris Brown']
Meek_Mill = df.loc[df['Artist']=='Meek Mill']
PARTYNEXTDOOR =df.loc[df['Artist']=='PARTYNEXTDOOR']
Rick_Ross = df.loc[df['Artist']=='Rick Ross']
Swae_Lee = df.loc[df['Artist']=='Swae Lee']
French_Montana = df.loc[df['Artist']=='French Montana']
Summer_Walker = df.loc[df['Artist']=='Summer Walker']
BlocBoy_JB = df.loc[df['Artist']=='BlocBoy JB']
Lil_Baby = df.loc[df['Artist']=='Lil Baby']

Bad_Bunny = Bad_Bunny.loc[pd.isnull(Bad_Bunny['featured-artist'])]
Chris_Brown = Chris_Brown.loc[pd.isnull(Chris_Brown['featured-artist'])]
Meek_Mill = Meek_Mill.loc[pd.isnull(Meek_Mill['featured-artist'])]
PARTYNEXTDOOR = PARTYNEXTDOOR.loc[pd.isnull(PARTYNEXTDOOR['featured-artist'])]
Rick_Ross = Rick_Ross.loc[pd.isnull(Rick_Ross['featured-artist'])]
Swae_Lee = Swae_Lee.loc[pd.isnull(Swae_Lee['featured-artist'])]
French_Montana = French_Montana.loc[pd.isnull(French_Montana['featured-artist'])]
Summer_Walker = Summer_Walker.loc[pd.isnull(Summer_Walker['featured-artist'])]
BlocBoy_JB = BlocBoy_JB.loc[pd.isnull(BlocBoy_JB['featured-artist'])]
Lil_Baby = Lil_Baby.loc[pd.isnull(Lil_Baby['featured-artist'])]

Bad_Bunny_ft = Bad_Bunny.loc[pd.isnull(Bad_Bunny['featured-artist'] != 'Drake')]
Chris_Brown_ft = Chris_Brown.loc[pd.isnull(Chris_Brown['featured-artist' != 'Drake'])]
Meek_Mill_ft = Meek_Mill.loc[pd.isnull(Meek_Mill['featured-artist' != 'Drake'])]
PARTYNEXTDOOR_ft = PARTYNEXTDOOR.loc[pd.isnull(PARTYNEXTDOOR['featured-artist' != 'Drake'])]
Rick_Ross_ft = Rick_Ross.loc[pd.isnull(Rick_Ross['featured-artist' != 'Drake'])]
Swae_Lee_ft = Swae_Lee.loc[pd.isnull(Swae_Lee['featured-artist' != 'Drake'])]
French_Montana_ft = French_Montana.loc[pd.isnull(French_Montana['featured-artist'] != 'Drake')]
Summer_Walker_ft = Summer_Walker.loc[pd.isnull(Summer_Walker['featured-artist'] != 'Drake')]
BlocBoy_JB_ft = BlocBoy_JB.loc[pd.isnull(BlocBoy_JB['featured-artist'] != 'Drake')]
Lil_Baby_ft = Lil_Baby.loc[pd.isnull(Lil_Baby['featured-artist'] != 'Drake')]


Bad_Bunny_Q3 = Bad_Bunny['Streams'].describe()['mean']
Chris_Brown_Q3 = Chris_Brown['Streams'].describe()['mean']
Meek_Mill_Q3 = Meek_Mill['Streams'].describe()['mean']
PARTYNEXTDOOR_Q3 = PARTYNEXTDOOR['Streams'].describe()['mean']
Rick_Ross_Q3 = Rick_Ross['Streams'].describe()['mean']
Swae_Lee_Q3 = Swae_Lee['Streams'].describe()['mean']
French_Montana_Q3 = French_Montana['Streams'].describe()['mean']
Summer_Walker_Q3 = Summer_Walker['Streams'].describe()['mean']
BlocBoy_JB_Q3 = BlocBoy_JB['Streams'].describe()['mean']
Lil_Baby_Q3 = Lil_Baby['Streams'].describe()['mean']

# %%
artistRow = [Bad_Bunny, Chris_Brown, Meek_Mill, PARTYNEXTDOOR, Rick_Ross, Swae_Lee, French_Montana, Summer_Walker, BlocBoy_JB, Lil_Baby]
artists = ['Bad Bunny', 'Chris Brown', 'Meek Mill', 'PARTYNEXTDOOR', 'Rick Ross', 'Swae Lee', 'French Montana', 'Summer Walker', 'BlocBoy JB', 'Lil Baby']
list75 = [Bad_Bunny_Q3, Chris_Brown_Q3, Meek_Mill_Q3, PARTYNEXTDOOR_Q3, Rick_Ross_Q3, Swae_Lee_Q3, French_Montana_Q3, Summer_Walker_Q3, BlocBoy_JB_Q3, Lil_Baby_Q3]
streams = []
for stream in featured_Drake['Streams']:
    streams.append(stream)

for i in range(10):
    if pd.isnull(list75[i]):
        list75[i] = 0
    print('{} sings with {} streams.  Drake sings with {} streams'.format(artists[i], list75[i], streams[i]))
    print('------------------------------')
# Out:
# Bad Bunny sings with 11222046.75 streams.  Drake sings with 19630428 streams
# ------------------------------
# Chris Brown sings with 7223124.0 streams.  Drake sings with 18038661 streams
# ------------------------------
# Meek Mill sings with 0 streams.  Drake sings with 17539582 streams
# ------------------------------
# PARTYNEXTDOOR sings with 0 streams.  Drake sings with 9344195 streams
# ------------------------------
# Rick Ross sings with 0 streams.  Drake sings with 8489195 streams
# ------------------------------
# Swae Lee sings with 0 streams.  Drake sings with 7391277 streams
# ------------------------------
# French Montana sings with 0 streams.  Drake sings with 6701673 streams
# ------------------------------
# Summer Walker sings with 0 streams.  Drake sings with 6428530 streams
# ------------------------------
# BlocBoy JB sings with 0 streams.  Drake sings with 5532858 streams
# ------------------------------
# Lil Baby sings with 6277544.0 streams.  Drake sings with 4761754 streams
# ------------------------------

# %%
for i in range(10):
    if (list75[i] < streams[i]):
        print('Drake does good in {}\'s song'.format(artists[i]))
    else:
        print('Drake sucks a big one')
# Out:
# Drake does good in Bad Bunny's song
# Drake does good in Chris Brown's song
# Drake does good in Meek Mill's song
# Drake does good in PARTYNEXTDOOR's song
# Drake does good in Rick Ross's song
# Drake does good in Swae Lee's song
# Drake does good in French Montana's song
# Drake does good in Summer Walker's song
# Drake does good in BlocBoy JB's song
# Drake sucks a big one
