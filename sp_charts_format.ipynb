# %%
import spotipy
import numpy as np
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

### Formats Spotify Chart CSV files to include audio features, popularity, and release date ###
def chart_expand(csv_path):
    ## Set your client variables
    # client_id = 
    # client_secret = 
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
    top_df = pd.read_csv(csv_path, header=1, sep=',') #Makes the 2nd row the column headers, 1st row is junk
    acousticness = [] #Lists store specified attributes of tracks in the order they appear in top_df, so they will appear in the correct row
    danceability = []
    energy = []
    instrumentalness = []
    liveness = []
    loudness = []
    speechiness = []
    tempo = []
    valence = []
    popularity = []
    release_date = []

    for url in top_df['URL']:
        features = sp.audio_features(url)
        track_info = sp.track(url)
        acousticness.append(features[0]['acousticness'])
        danceability.append(features[0]['danceability'])
        energy.append(features[0]['energy'])
        instrumentalness.append(features[0]['instrumentalness'])
        liveness.append(features[0]['liveness'])
        loudness.append(features[0]['loudness'])
        speechiness.append(features[0]['speechiness'])
        tempo.append(features[0]['tempo'])
        valence.append(features[0]['valence'])
        popularity.append(track_info['popularity'])
        release_date.append(track_info['album']['release_date'])

    top_df['acousticness'] = acousticness #Creates the attribute columns and populates them
    top_df['danceability'] = danceability
    top_df['energy'] = energy
    top_df['instrumentalness'] = instrumentalness
    top_df['liveness'] = liveness
    top_df['loudness'] = loudness
    top_df['speechiness'] = speechiness
    top_df['tempo'] = tempo
    top_df['valence'] = valence
    top_df['popularity'] = popularity
    top_df['release_date'] = release_date
    top_df.to_csv(csv_path + '_formatted.csv')
    print('Done')
# Out:
#      Unnamed: 0  Position                Track Name            Artist  \
# 0             0         1           Blinding Lights        The Weeknd
# 1             1         2                   The Box       Roddy Ricch
# 2             2         3              Dance Monkey       Tones and I
# 3             3         4           Don't Start Now          Dua Lipa
# 4             4         5  Intentions (feat. Quavo)     Justin Bieber
# ..          ...       ...                       ...               ...
# 195         195       196               Truth Hurts             Lizzo
# 196         196       197             bury a friend     Billie Eilish
# 197         197       198                  I.F.L.Y.             Bazzi
# 198         198       199                 Moonlight      XXXTENTACION
# 199         199       200                  Takeaway  The Chainsmokers
#
#       Streams                                                URL  \
# 0    43316941  https://open.spotify.com/track/0sf12qNH5qcw8qp...
# 1    39070218  https://open.spotify.com/track/0nbXyq5TXYPCO7p...
# 2    38072447  https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# 3    33460126  https://open.spotify.com/track/6WrI0LAC5M1Rw2M...
# 4    29542408  https://open.spotify.com/track/4umIPjkehX1r7uh...
# ..        ...                                                ...
# 195   5024683  https://open.spotify.com/track/3HWzoMvoF3TQfYg...
# 196   5020303  https://open.spotify.com/track/4SSnFejRGlZikf0...
# 197   5002595  https://open.spotify.com/track/4a6q8CR2hzLk2pl...
# 198   4982070  https://open.spotify.com/track/0JP9xo3adEtGSdU...
# 199   4966053  https://open.spotify.com/track/3g0mEQx3NTanacL...
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0         0.00147         0.513   0.796          0.000209    0.0938    -4.075
# 1         0.10400         0.896   0.586          0.000000    0.7900    -6.687
# 2         0.68800         0.825   0.593          0.000161    0.1700    -6.401
# 3         0.01250         0.794   0.793          0.000000    0.0952    -4.521
# 4         0.30000         0.806   0.546          0.000000    0.1020    -6.637
# ..            ...           ...     ...               ...       ...       ...
# 195       0.11000         0.715   0.624          0.000000    0.1230    -3.046
# 196       0.74000         0.905   0.389          0.162000    0.1060   -14.505
# 197       0.37900         0.812   0.519          0.000000    0.1300    -4.823
# 198       0.55600         0.921   0.537          0.004040    0.1020    -5.723
# 199       0.12600         0.528   0.511          0.000000    0.1010    -8.144
#
#      speechiness    tempo  valence  popularity release_date
# 0         0.0629  171.017    0.345         100   2019-11-29
# 1         0.0559  116.971    0.642          99   2019-12-06
# 2         0.0988   98.078    0.540          76   2019-05-10
# 3         0.0842  123.941    0.677          97   2019-10-31
# 4         0.0575  147.986    0.874          89   2020-02-14
# ..           ...      ...      ...         ...          ...
# 195       0.1140  158.087    0.412          80   2019-04-19
# 196       0.3320  120.046    0.196          85   2019-03-29
# 197       0.0385  104.954    0.554          84   2019-08-09
# 198       0.0804  128.009    0.711          84   2018-03-16
# 199       0.0324  100.100    0.351          84   2019-12-06
#
# [200 rows x 17 columns]
